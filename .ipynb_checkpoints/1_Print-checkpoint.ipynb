# %%
print("Hello")
# Out:
# Hello

# %%
print('''Welcome to Artificial Intelligence
and Data Scicence''')
# Out:
# Welcome to Artificial Intelligence
# and Data Scicence

# %%
print('Weclome to AI and Data Science')
# Out:
# Weclome to AI and Data Science

# %%
print(" Welcome to AI \n and DS")
# Out:
#  Welcome to AI
#  and DS

# %%
print('This is Jhon\'s book')
# Out:
# This is Jhon's book

# %%
print("This is mine book \"Wisdom\"")
# Out:
# This is mine book "Wisdom"
