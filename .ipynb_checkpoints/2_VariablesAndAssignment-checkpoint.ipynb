# %%
num1=45
num2=56
add=num1+num2
print(add)
# Out:
# 101

# %%
print("The addition of Two number")
print("The num1 is :", num1)
print("The num2 is :", num2)
print("The Result of Two addition value is :", add)
# Out:
# The addition of Two number
# The num1 is : 45
# The num2 is : 56
# The Result of Two addition value is : 101

# %%
# use # keyword to comment the statement
# To get input data from the user
num1=int(input("Enter the Number1 :"))
num2=int(input("Enter the number2 :"))
print("The Two addition of value is :", num1+num2)
# Out:
# Enter the Number1 : 55
# Enter the number2 : 67
# The Two addition of value is : 122

# %%
result=print(num1+num2)
print(result)
# Out:
# 122
# None
