# %%
#1.Find the error in the following Python code:
import math
print(math.sqrt(16)) # math class name case sensitive, hence got name "Math" not defined issue. Issue addressed.
# Out:
# 4.0

# %%
#2.Find the error in the following Python code:
def my_function(x):
    x += 5
    print(x)

x = 10 # cannot access local variable, hence pass the local value through argument
my_function(x)
# Out:
# 15

# %%
#3.x = 5  
if x := 10: # Invalid syntax error, we can use walrus operator to assign value to the x variable
    print("x is 10")
# Out:
# x is 10

# %%
#4.
numbers = [5, 3, 8, 2]
numbers.sort()
print(numbers) # Sort method do not directly use in print method because it does not return new modified list
# Out:
# [2, 3, 5, 8]

# %%
#5.
def square(n):
    return n * n    # Here return keyword missing, shoud return the value

print(square(4))
# Out:
# 16

# %%
#6.
my_tuple = (1, 2, 3)
list1=list(my_tuple)
list1[1] = 5 # tuple cannot modify the item, instead we can convert the tuple into list and then add item then convert into tuple
my_tuple=tuple(list1)
print(my_tuple)
# Out:
# (1, 5, 3)

# %%
#7.
name = "Alice"
age = 25
print("My name is %s and I am %d years old" % (name,age) ) # Not enough argument for formating string , should pass two argument instead of 1
# Out:
# My name is Alice and I am 25 years old

# %%
#8.
a = [1, 2, 3]
b = [1, 2, 3]
if a == b:    #is an identity, it's checking both variable sharing same memory location condition false hence not print the statement.
    print("Lists are equal") # use equal operator to validate both a and b list are equal or not
# Out:
# Lists are equal

# %%
#9.
for i in range(5, 1,-1):#start value must be less compare with stop value else it could not reach the stop value as per range logic,hence use step value -1
    print(i)
# Out:
# 5
# 4
# 3
# 2

# %%
#10.
student = {"name": "John", "age": 20}
print(student["name"]) # Keyerror name key must be come in double quotes
# Out:
# John
