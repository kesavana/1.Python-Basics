# %%
#1.What is wrong with the following function definition, and how do you fix it?


def say_hello(name): #missing semi colon
    print("Hello, " + name)
say_hello("Kesavan")
# Out:
# Hello, Kesavan

# %%
#2.What error will occur in the following code, and how do you fix it?


age = 25
print("I am " + str(age) + " years old") # Type conversion error can only concatenate str
# Out:
# I am 25 years old

# %%
#3.Question:
#What is the issue with the following code?
message = "Kesavan"
def greet(): 
    message = "Hello" # missing return statement
    return message
print(message) # function local variable cannot access directly outside of funtion in print statement
print(greet())
# Out:
# Kesavan
# Hello

# %%
#4.What error will occur in the following code, and how do you fix it?

def add(a, b):
    return a + b

print(add(5,5)) # missing an argument instead of 2 arguments
# Out:
# 10

# %%
#5.What is wrong with this code?

def is_even(n):
    if n % 2 == 1:
        return True
    else:
        return False # No error in this code

print(is_even(5))
# Out:
# True

# %%
#6.What happens when you run this code?

num = int(10) #Value error remove double quotes and a if want to print 10 else change data type as str instead of int to print string value
print(num)
# Out:
# 10

# %%
#7.What will happen when you run the following code?


numbers = [1, 2, 3, 4]
numbers.sort(reverse=True)# Here we need to one by one, because sort method can change the list order directly 
# So calling reverse method directly with reverse method it will through error, we can pass reverse=True as argument in sort method 
print(numbers)
# Out:
# [4, 3, 2, 1]

# %%
#8.What is the issue with this code?


numbers = [1, 2, 3]
numbers.append(4) # here this statement trying to overwrite the list with same variable hence it will return None. So remove assignment statement with same variable
print(numbers)
# Out:
# [1, 2, 3, 4]

# %%
#9.What will happen when you run the following code?


count = 10

def increment(count):
    count += 1 # cannot access global variable without passing as an argument
    print(count) # Cannot access local variable "count" where it is not associated with a value


increment(count)
print(count)
# Out:
# 11
# 10

# %%
#10.What error will occur in the following code?

text = "Python"
print(text[:len(text)]) #Here text string length is out of index range
# Out:
# Python
