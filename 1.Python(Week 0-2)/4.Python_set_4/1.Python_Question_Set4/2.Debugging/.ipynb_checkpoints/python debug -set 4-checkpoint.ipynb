# %%
#1.Identify and fix the syntax error in the following code:


age = 18
if age >= 18: #mising colon
    print("You are eligible to vote")
# Out:
# You are eligible to vote

# %%
#2.Question:
#$What error will occur in the following code?


def greet():
    print("Hello, World!")

#greet_user() # undefined funtion name
greet()
# Out:
# Hello, World!

# %%
#3.Identify the error in this code:

name = "Alice"
age = 25
print("My name is " + name + " and I am " + str(age) + " years old.") #Type conversion error int can't concatenate directly with string
# Out:
# My name is Alice and I am 25 years old.

# %%
#4.Question:
#What will happen when you run this code?

a = 10
b = 0
try:
    result = a / b # zero devided by zero
    print(result)
except ZeroDivisionError:
    print("Divided by Zero error")
# Out:
# Divided by Zero error

# %%
#5.What error will occur in the following code?

num = str("xyz") #Value error cannot convert string literal value into integer
print(num)
# Out:
# xyz

# %%
#6.Identify the issue in this code:

data = {"name": "John", "age": 30}
print(data["name"]) #Wrong key declared instead of name or age
# Out:
# John

# %%
#7.What will happen when you run this code?
num = 1
while num < 5: #It will run infinitely , need to add increment expression to meet the condition
    print(num)
    num+=1
# Out:
# 1
# 2
# 3
# 4

# %%
#8.What is wrong with this code?

fruits = ("apple", "banana", "cherry")
print(fruits[2]) # The index value is out of range
# Out:
# cherry

# %%
#9.What will happen when you run this code?

text = "hello world" +"!"
#text.append("!") # no append method in string , can use + operator to concatine
print(text)
# Out:
# hello world!

# %%
#10.What is wrong with the following code?

import random # Incorrect module name called instead of random
print(random.randint(1, 10))
# Out:
# 10
