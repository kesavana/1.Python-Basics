# %%
#1. Convert a List of Strings to Uppercase
#Question: Write a Python program to convert all strings in the list ["apple", "banana", "cherry"] to uppercase.
fruits=["apple", "banana", "cherry"]
for i in fruits:
    print(i.upper())
# Out:
# APPLE
# BANANA
# CHERRY

# %%
#2. Merge Two Dictionaries
#Question: Write a Python program to merge two dictionaries:

dict1 = {'a': 10, 'b': 20}  
dict2 = {'c': 30, 'd': 40}
dict4={'e':56,'f':43}
dict1.update(dict2)
dict3=dict1 | dict2 | dict4 # using merge (|)operator to merge dictionary
print(dict1)
print(dict3)
# Out:
# {'a': 10, 'b': 20, 'c': 30, 'd': 40}
# {'a': 10, 'b': 20, 'c': 30, 'd': 40, 'e': 56, 'f': 43}

# %%
#3. Find the Intersection of Two Lists
#Question: Write a Python program to find the common elements between the two lists:


list1 = [1, 2, 3, 4, 5]  
list2 = [4, 5, 6, 7, 8]
for i in list1:
    for j in list2:
        if(i==j):
            print(i)
# Out:
# 4
# 5

# %%
#4. Find the Length of Each Word in a Sentence
#Question: Write a Python program to print the length of each word in the sentence "Python is fun and powerful".
sentence="Python is fun and powerful"
list1=sentence.split(' ')
for i in list1:
    print(f"The '{i}' length is {len(i)}")
# Out:
# The 'Python' length is 6
# The 'is' length is 2
# The 'fun' length is 3
# The 'and' length is 3
# The 'powerful' length is 8

# %%
#5. Find the Sum of All Elements in a 2D List
#Question: Write a Python program to find the sum of all elements in the 2D list:

matrix = [[1, 2, 3], [4, 5, 6], [7, 8, 9]]
tot_sum=0
for row in matrix:
    for num in row:
        tot_sum+=num

print(f"The total sum of all element is {tot_sum}")

total=sum(num for row in matrix for num in row) # shortest way to get sum of all the elements 
print(f"The total sum of all element is {total}")
# Out:
# The total sum of all element is 45
# The total sum of all element is 45
